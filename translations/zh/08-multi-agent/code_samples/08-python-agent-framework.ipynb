# %% [markdown]
# # 🤝 使用 GitHub 模型构建多代理工作流系统 (Python)
#
# ## 📋 学习目标
#
# 本笔记本演示如何使用 Microsoft Agent Framework 和 GitHub 模型构建复杂的多代理系统。您将学习如何通过结构化工作流协调多个专业代理共同解决复杂问题。
#
# **您将构建的多代理功能：**
# - 👥 **代理协作**：多个代理共同努力实现共同目标
# - 🔄 **工作流编排**：结构化协调代理之间的交互
# - 🎭 **角色专业化**：具有不同个性和专业领域的代理
# - 📋 **质量保证**：通过代理协作进行审查和改进
#
# ## 🎯 多代理架构概念
#
# ### 核心多代理原则
# - **分工合作**：每个代理专注于特定领域的专业知识
# - **协作决策**：代理审查并改进彼此的工作
# - **工作流协调**：结构化的交接和沟通模式
# - **质量提升**：通过多视角分析进行迭代改进
#
# ### 代理交互模式
# - **顺序处理**：按顺序参与的线性工作流
# - **同行评审**：代理验证并改进彼此的输出
# - **层级结构**：主导代理协调下属专家
# - **共识构建**：多个代理共同参与最终决策
#
# ## 🏗️ 技术架构
#
# ### 工作流系统组件
# - **Microsoft Agent Framework**：支持高级工作流的 Python 实现
# - **WorkflowBuilder**：声明式工作流定义和执行引擎
# - **代理协调**：结构化的通信和交接机制
# - **事件驱动处理**：基于代理输出的反应式工作流执行
#
# ### 多代理流程
# ```python
# User Request → Agent 1 (Specialist) → Agent 2 (Reviewer) → Quality Check
#                 ↓                      ↓                    ↓
#          Initial Solution → Review & Feedback → Refined Output → Final Result
# ```
#
# ## 🎭 代理角色示例
#
# ### 酒店礼宾系统
# 本笔记本演示了一个具有专业角色的旅行推荐系统：
#
# #### 🏨 **前台代理**
# - **专业领域**：旅行推荐和当地知识
# - **个性特点**：高效、经验丰富、沟通简洁
# - **职责**：生成初步旅行建议和活动推荐
#
# #### 🎩 **礼宾代理**
# - **专业领域**：真实的当地体验和质量评估
# - **个性特点**：挑剔，专注于非游客化的推荐
# - **职责**：审查并优化旅行建议以确保真实性
#
# ## 🔧 技术实现
#
# ### 工作流架构
# - **代理定义**：专业指令和个性配置
# - **工作流构建器**：带事件处理的声明式工作流定义
# - **通信协议**：代理之间的结构化消息传递
# - **结果聚合**：结合多个代理视角的输出
#
# ### 事件驱动协调
# - **WorkflowEvent**：代理激活和交接的触发点
# - **OutputEvent**：代理之间的结构化数据交换
# - **质量门**：工作流过程中的验证检查点
# - **反馈循环**：通过代理协作进行迭代优化
#
# ## ⚙️ 前提条件与设置
#
# **所需依赖项：**
# ```bash
#
#
# pip install agent-framework-core  -U
# ```
#
# **环境配置 (.env 文件)：**
# ```env
# GITHUB_TOKEN=your_github_personal_access_token
# GITHUB_ENDPOINT=https://models.inference.ai.azure.com
# GITHUB_MODEL_ID=gpt-4o-mini
# ```
#
# ## 🎨 多代理设计模式
#
# ### 1. **生产者-消费者模式**
# - 专业代理生成内容供其他代理审查
# - 明确的交接点和数据交换协议
# - 通过独立审查进行质量保证
# - 迭代优化和改进周期
#
# ### 2. **委员会模式**
# - 多个代理贡献不同视角
# - 通过结构化讨论达成共识
# - 民主决策，权重意见
# - 冲突解决和平局机制
#
# ### 3. **层级模式**
# - 主导代理协调专业下属
# - 明确的权威结构和决策流程
# - 复杂决策的升级路径
# - 性能监控和质量控制
#
# ### 4. **流水线模式**
# - 专业阶段的顺序处理
# - 每个代理在其专业领域增加价值
# - 通过并行处理提高效率
# - 每个阶段的错误处理和恢复
#
# ## 🚀 高级多代理功能
#
# ### 工作流编排
# - **动态路由**：基于上下文的代理选择和路由
# - **并行处理**：高效的并发代理执行
# - **错误恢复**：优雅处理代理失败和重试
# - **性能监控**：跟踪工作流执行和优化
#
# ### 代理通信
# - **结构化消息**：类型安全的通信协议
# - **上下文保留**：维护代理间的对话历史
# - **元数据传递**：超越文本内容的丰富信息交换
# - **事件广播**：用于协调的发布-订阅模式
#
# ### 质量保证
# - **多视角审查**：不同代理带来独特观点
# - **迭代优化**：通过协作逐步改进
# - **验证检查点**：工作流中的质量门
# - **性能指标**：衡量协作效率
#
# ## 📊 用例与应用
#
# ### 业务流程自动化
# - 文档审查和审批工作流
# - 客户服务升级系统
# - 质量保证和合规检查
# - 多阶段内容创建和编辑
#
# ### 研究与分析
# - 研究论文的同行评审系统
# - 多分析师的财务分析
# - 协作报告撰写和事实核查
# - 学术论文审查和改进
#
# ### 创意协作
# - 编辑和审稿人的内容创作
# - 多视角创意头脑风暴
# - 迭代设计和反馈系统
# - 协作故事创作和世界构建
#
# 准备好编排智能多代理协作了吗？让我们构建一个代理像高效团队一样协作的系统吧！🌟🤖

# %%
! pip install agent-framework-core -U
# Out:
# ...
#   Attempting uninstall: agent-framework-core
#     Found existing installation: agent-framework-core 1.0.0b260116
#     Uninstalling agent-framework-core-1.0.0b260116:
#       Successfully uninstalled agent-framework-core-1.0.0b260116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# agent-framework 1.0.0b260114 requires agent-framework-core[all]==1.0.0b260114, but you have agent-framework-core 1.0.0b260123 which is incompatible.
# ...
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# 🤖 Import Multi-Agent Workflow Components
# OpenAIChatClient: GitHub Models integration for agent communication
# WorkflowEvent, WorkflowBuilder: Core workflow orchestration classes
# WorkflowOutputEvent: Structured event handling for agent coordination
# ChatAgent: Agent class for creating conversational agents with a shared chat client
from agent_framework.openai import OpenAIChatClient
from agent_framework import WorkflowEvent, WorkflowBuilder, WorkflowOutputEvent, ChatAgent

# %%
# 📦 Import Configuration and Environment Management
import os                      # Environment variable access for secure configuration
from dotenv import load_dotenv # Secure loading of API credentials and settings

# %%
# 🔧 Load Multi-Agent Workflow Configuration  
# Load environment variables for secure GitHub Models access
# Required: GITHUB_ENDPOINT, GITHUB_TOKEN, GITHUB_MODEL_ID for agent communication
load_dotenv()
# Out:
# True

# %%
# 🔗 Initialize Shared Chat Client for Multi-Agent Communication
# Create a unified client that all agents in the workflow will use
# This ensures consistent API access and efficient resource utilization
chat_client = OpenAIChatClient(
    base_url=os.environ.get("GITHUB_ENDPOINT"),    # GitHub Models API endpoint
    api_key=os.environ.get("GITHUB_TOKEN"),        # Authentication token
    model_id=os.environ.get("GITHUB_MODEL_ID")  # Model for all agents in workflow
)

# %%
# 🎩 Agent 1: Hotel Concierge - Quality Reviewer Role
# This agent specializes in evaluating travel recommendations for authenticity
# Acts as the second stage in our multi-agent workflow for quality assurance
REVIEWER_NAME = "Concierge"
REVIEWER_INSTRUCTIONS = """
    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.
    
    Your role in this multi-agent workflow:
    - Review travel recommendations from the Front Desk agent
    - Assess whether suggestions provide authentic, non-touristy experiences
    - Approve recommendations that meet high standards for local authenticity
    - Provide constructive feedback for refinement without giving specific examples
    
    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.
    """

# %%
FRONTDESK_NAME = "FrontDesk"
FRONTDESK_INSTRUCTIONS = """
    You are a Front Desk Travel Agent with ten years of experience and are known for brevity as you deal with many customers.
    The goal is to provide the best activities and locations for a traveler to visit.
    Only provide a single recommendation per response.
    You're laser focused on the goal at hand.
    Don't waste time with chit chat.
    Consider suggestions when refining an idea.
    """

# %%
hasattr(chat_client, "create_agent")
#验证chat_client是否有create_agent方法
# Out:
# False

# %%
writer_agent = ChatAgent(chat_client=chat_client, instructions=REVIEWER_INSTRUCTIONS, name=REVIEWER_NAME)

agent_reviewer = ChatAgent(chat_client=chat_client, instructions=FRONTDESK_INSTRUCTIONS, name=FRONTDESK_NAME)

# %%
workflow = WorkflowBuilder().set_start_executor(writer_agent).add_edge(writer_agent, agent_reviewer).build()

# %%
class DatabaseEvent(WorkflowEvent):
    """A simple WorkflowEvent subclass representing database-related events."""
    pass

# %%
async for event in workflow.run_stream("I would like to go to Paris."):
        if isinstance(event, DatabaseEvent):
            print(f"{event}")
        elif isinstance(event, WorkflowOutputEvent):
            print(f"Workflow output: {event.data}")
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/chat/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-4edafe3c-d1c2-4e0b-a853-b365d93790e8', 'json_data': {'messages': [{'role': 'system', 'content': [{'type': 'text', 'text': '\n    You are an experienced hotel concierge who has strong opinions about providing the most local and authentic experiences for travelers.\n\n    Your role in this multi-agent workflow:\n    - Review travel recommendations from the Front Desk agent\n    - Assess whether suggestions provide authentic, non-touristy experiences\n    - Approve recommendations that meet high standards for local authenticity\n    - Provide constructive feedback for refinement without giving specific examples\n\n    Always focus on the quality and authenticity of experiences rather than just popular tourist destinations.\n    '}]}, {'role': 'user', 'content': [{'type': 'text', 'text': 'I would like to go to Paris.'}]}, {'role': 'assistant'
# ...

# %% [markdown]
# ---
#
# **免责声明**：
# 本文档使用AI翻译服务 [Co-op Translator](https://github.com/Azure/co-op-translator) 进行翻译。尽管我们努力确保翻译的准确性，但请注意，自动翻译可能包含错误或不准确之处。原始语言的文档应被视为权威来源。对于关键信息，建议使用专业人工翻译。我们不对因使用此翻译而产生的任何误解或误读承担责任。
